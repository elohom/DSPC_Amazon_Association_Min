# %%
import sys

# %% [markdown]
# ## Part 1 - Figure out what customer ids appear multiple times - this will reduce the memory we need later
#
# The plan is that this will enable us to handle most of the lines of the file easily. Since, it is only resource intensive where need to handle custtomer ids that appear mutliple times.

# %%
line_no = 0
all_cust_ids = set()   # will contain all unique cust_ids
multi_cust_ids = set()   # will contain cust_ids that appear multiple times
prod_cats = ['Wireless', 'Books', 'Digital_Ebook_Purchase', 'Video DVD',
       'Electronics', 'Digital_Music_Purchase', 'Home', 'Shoes',
       'Digital_Video_Download', 'Musical Instruments', 'Camera',
       'Kitchen', 'Baby', 'Music', 'Home Improvement', 'Beauty',
       'Office Products', 'Video', 'Automotive', 'Apparel', 'Jewelry',
       'Outdoors', 'PC', 'Toys', 'Sports', 'Health & Personal Care',
       'Lawn and Garden', 'Tools', 'Major Appliances',
       'Home Entertainment', 'Video Games', 'Watches', 'Pet Products',
       'Luggage', 'Grocery', 'Mobile_Apps', 'Digital_Software',
       'Furniture', 'Software', 'Mobile_Electronics', 'Gift Card',
       'Digital_Video_Games', 'Personal_Care_Appliances']

# read the file line by line avoiding loading entire file into memory
for line in open('/media/paul/Data/datasets/DSPC_reviews_association_mining/raw_transactions_file.csv'):
    # keep track of line no
    line_no = line_no + 1
    
    # There is an encoding error after line 124343000 hence stop before this (we are nearly at the end of the file anyway)
    if line_no == 124343000:
        break
    
    # print progress every 1,000,000 lines
    if ((line_no%1000000) == 0):
        print('Processing line ' + str(line_no) + '(' + str(round((line_no/124343000)*100,2)) + '%)')
    
    # break into cells
    cells = line.strip('').split(',')
    
    # Check line has expected number of cells
    if(len(cells) != 4):
        #print("Bad line: " + str(line_no) + " - incorrect number of cells")
        print("Xc,", end='')
        continue
        
    # Check the prod_cat is valid
    if(cells[1] not in prod_cats):
        #print("Bad line: " + str(line_no) + " - invalid product category")
        print("Xp,", end='')
        continue
    
    # read the customer id
    cust_id = cells[0]
    
    # check whether we have seen this id before?
    pre_add_length = len(all_cust_ids) # check the length
    
    # add the id to the set
    all_cust_ids.add(cust_id) 
    
    # if the id has been seen before then len would have not increased,
    # hence we know this cust_id is appearing for an another time.
    if pre_add_length == len(all_cust_ids):
        multi_cust_ids.add(cust_id)

del all_cust_ids

print("Found " + str(len(multi_cust_ids)) + " id appearing multiple reviews")
print(str(round(sys.getsizeof(multi_cust_ids) / 1000000000, 2)) + "GB")
# Out:
# Processing line 1000000(0.8%)
# Processing line 2000000(1.61%)
# Processing line 3000000(2.41%)
# Xc,Processing line 4000000(3.22%)
# Xc,Xp,Processing line 5000000(4.02%)
# Xc,Xp,Xp,Xp,Processing line 6000000(4.83%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 7000000(5.63%)
# Xp,Xp,Xp,Xp,Processing line 8000000(6.43%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 9000000(7.24%)
# Processing line 10000000(8.04%)
# Processing line 11000000(8.85%)
# Processing line 12000000(9.65%)
# Processing line 13000000(10.45%)
# Processing line 14000000(11.26%)
# Xp,Xp,Processing line 15000000(12.06%)
# Processing line 16000000(12.87%)
# Xp,Xp,Processing line 17000000(13.67%)
# Processing line 18000000(14.48%)
# Processing line 19000000(15.28%)
# Processing line 20000000(16.08%)
# Processing line 21000000(16.89%)
# Xp,Processing line 22000000(17.69%)
# Processing line 23000000(18.5%)
# Xp,Xp,Xp,Xc,Processing line 24000000(19.3%)
# Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xc,Xc,Xp,Xc,Xp,Xc,Processing line 25000000(20.11%)
# Xc,Xc,Xp,Xp,Xp,Xc,Xc,Xp,Xp,Xc,Xp,Xp,Xc,Xc,Xp,Xc,Xc,Xp,Xp,Xp,Xc,Processing line 26000000(20.91%)
# Xp,Xp,Xp,Xc,Xp,Xc,Xc,Xc,Xc,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xc,Xc,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Processing line 27000000(21.71%)
# Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Processing line 28000000(22.52%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 29000000(23.32%)
# Processing line 30000000(24.13%)
# Processing line 31000000(24.93%)
# Processing line 32000000(25.74%)
# Processing line 33000000(26.54%)
# Processing line 34000000(27.34%)
# Xp,Processing line 35000000(28.15%)
# Processing line 36000000(28.95%)
# Processing line 37000000(29.76%)
# Processing line 38000000(30.56%)
# Processing line 39000000(31.36%)
# Processing line 40000000(32.17%)
# Processing line 41000000(32.97%)
# Processing line 42000000(33.78%)
# Xp,Processing line 43000000(34.58%)
# Processing line 44000000(35.39%)
# Xc,Xp,Processing line 45000000(36.19%)
# Xc,Xp,Processing line 46000000(36.99%)
# Xp,Xp,Processing line 47000000(37.8%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 48000000(38.6%)
# Xc,Xc,Processing line 49000000(39.41%)
# Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xc,Processing line 50000000(40.21%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 51000000(41.02%)
# Xp,Xp,Xp,Xp,Xp,Xp,Processing line 52000000(41.82%)
# Xp,Xp,Processing line 53000000(42.62%)
# Xp,Xp,Xp,Processing line 54000000(43.43%)
# Processing line 55000000(44.23%)
# Processing line 56000000(45.04%)
# Processing line 57000000(45.84%)
# Processing line 58000000(46.65%)
# Xp,Processing line 59000000(47.45%)
# Processing line 60000000(48.25%)
# Xp,Processing line 61000000(49.06%)
# Xp,Processing line 62000000(49.86%)
# Processing line 63000000(50.67%)
# Processing line 64000000(51.47%)
# Processing line 65000000(52.27%)
# Processing line 66000000(53.08%)
# Xp,Xp,Xp,Processing line 67000000(53.88%)
# Xp,Xp,Xp,Processing line 68000000(54.69%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xc,Xp,Xc,Xp,Xp,Processing line 69000000(55.49%)
# Xc,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 70000000(56.3%)
# Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 71000000(57.1%)
# Processing line 72000000(57.9%)
# Processing line 73000000(58.71%)
# Processing line 74000000(59.51%)
# Processing line 75000000(60.32%)
# Xp,Processing line 76000000(61.12%)
# Xp,Processing line 77000000(61.93%)
# Xp,Xp,Xp,Xp,Xp,Processing line 78000000(62.73%)
# Xc,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Processing line 79000000(63.53%)
# Xp,Xc,Xc,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Processing line 80000000(64.34%)
# Xc,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Processing line 81000000(65.14%)
# Xp,Xp,Xp,Xp,Xp,Processing line 82000000(65.95%)
# Xp,Xp,Xp,Processing line 83000000(66.75%)
# Xp,Processing line 84000000(67.56%)
# Xp,Xp,Xp,Processing line 85000000(68.36%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 86000000(69.16%)
# Processing line 87000000(69.97%)
# Processing line 88000000(70.77%)
# Processing line 89000000(71.58%)
# Processing line 90000000(72.38%)
# Processing line 91000000(73.18%)
# Processing line 92000000(73.99%)
# Processing line 93000000(74.79%)
# Processing line 94000000(75.6%)
# Xp,Processing line 95000000(76.4%)
# Xp,Xp,Processing line 96000000(77.21%)
# Xp,Processing line 97000000(78.01%)
# Processing line 98000000(78.81%)
# Xp,Xp,Processing line 99000000(79.62%)
# Xc,Xp,Xp,Xp,Processing line 100000000(80.42%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 101000000(81.23%)
# Xc,Xp,Xc,Processing line 102000000(82.03%)
# Xp,Processing line 103000000(82.84%)
# Xp,Processing line 104000000(83.64%)
# Processing line 105000000(84.44%)
# Processing line 106000000(85.25%)
# Xc,Xc,Xp,Xp,Xp,Xp,Processing line 107000000(86.05%)
# Processing line 108000000(86.86%)
# Processing line 109000000(87.66%)
# Xc,Processing line 110000000(88.46%)
# Processing line 111000000(89.27%)
# Processing line 112000000(90.07%)
# Xp,Processing line 113000000(90.88%)
# Processing line 114000000(91.68%)
# Processing line 115000000(92.49%)
# Xp,Processing line 116000000(93.29%)
# Xp,Xp,Processing line 117000000(94.09%)
# Xp,Processing line 118000000(94.9%)
# Xp,Xp,Xp,Xc,Xp,Processing line 119000000(95.7%)
# Xc,Xp,Processing line 120000000(96.51%)
# Xp,Xp,Xp,Processing line 121000000(97.31%)
# Xp,Xp,Xp,Processing line 122000000(98.12%)
# Xp,Xp,Xp,Xp,Xp,Processing line 123000000(98.92%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 124000000(99.72%)
# Xc,Xc,Xp,Found 14785289 id appearing multiple reviews
# 0.54GB

# %% [markdown]
# ## Part 2 - Handle the customer ids that appear once and prepare to handle to ids that appear multiple times

# %%
# list to contain handle the aggrgation when customers have purchased multi items
cust_id_to_prods = {}

# output file
f = open("/media/paul/Data/datasets/DSPC_reviews_association_mining/transactions_vertical.csv", "w")

# write the header
header = ''
for prod in prod_cats:
    header = header + prod + ','
header = header.strip(',')
f.write(header + '\n')

line_no = 0
# loop over file again, now processing only the cust_ids that appear once
for line in open('/media/paul/Data/datasets/DSPC_reviews_association_mining/raw_transactions_file.csv'):
    # keep track of line no
    line_no = line_no + 1
    
    # There is an encoding error after line 124343000 hence stop before this, (we are nearly at the end of the file anyway)
    if line_no == 124343000:
        break
        
    # print progress every 1,000,000 lines
    if ((line_no%1000000) == 0):
        print('Processing line ' + str(line_no) + '(' + str(round((line_no/124343000)*100,2)) + '%)')
    
    # break into cells
    cells = line.strip('').split(',')
    
    # Check line has expected number of cells
    if(len(cells) != 4):
        #print("Bad line: " + str(line_no) + " - incorrect number of cells")
        print("Xc,", end='')
        continue
        
    # Check the prod_cat is valid
    if(cells[1] not in prod_cats):
        #print("Bad line: " + str(line_no) + " - invalid product category")
        print("Xp,", end='')
        continue
    
    # read the customer id
    cust_id = cells[0]    
    prod = cells[1]
        
    # Handle the cases where they only bought one item, (easy, we have all the info we need)
    if cust_id not in multi_cust_ids:
        output_line = ''
        # write y for the product they bought and ? otherwise
        for prod_cat in prod_cats:
            if prod_cat == prod:
                output_line = output_line + 'y,'                
            else:
                output_line = output_line + '?,'
        output_line = output_line.strip(',') # remove unnecessary comma
        f.write(output_line + '\n')
    
    # Handle the cases where they bought multi items, (harder, we need to accumulate)
    else:
        # have we seen this cust_id before
        if cust_id in cust_id_to_prods.keys():
            # yes add to the set of prods
            cust_id_to_prods[cust_id].add(prod)
        else:
            # no create a a new set
            cust_id_to_prods[cust_id] = {prod}

f.close()
del multi_cust_ids

print("Aggregated the reviews of " + str(len(cust_id_to_prods)) + " customers")
print(str(round(sys.getsizeof(cust_id_to_prods) / 1000000000, 2)) + "GB")
# Out:
# Processing line 1000000(0.8%)
# Processing line 2000000(1.61%)
# Processing line 3000000(2.41%)
# Xc,Processing line 4000000(3.22%)
# Xc,Xp,Processing line 5000000(4.02%)
# Xc,Xp,Xp,Xp,Processing line 6000000(4.83%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 7000000(5.63%)
# Xp,Xp,Xp,Xp,Processing line 8000000(6.43%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 9000000(7.24%)
# Processing line 10000000(8.04%)
# Processing line 11000000(8.85%)
# Processing line 12000000(9.65%)
# Processing line 13000000(10.45%)
# Processing line 14000000(11.26%)
# Xp,Xp,Processing line 15000000(12.06%)
# Processing line 16000000(12.87%)
# Xp,Xp,Processing line 17000000(13.67%)
# Processing line 18000000(14.48%)
# Processing line 19000000(15.28%)
# Processing line 20000000(16.08%)
# Processing line 21000000(16.89%)
# Xp,Processing line 22000000(17.69%)
# Processing line 23000000(18.5%)
# Xp,Xp,Xp,Xc,Processing line 24000000(19.3%)
# Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xc,Xc,Xp,Xc,Xp,Xc,Processing line 25000000(20.11%)
# Xc,Xc,Xp,Xp,Xp,Xc,Xc,Xp,Xp,Xc,Xp,Xp,Xc,Xc,Xp,Xc,Xc,Xp,Xp,Xp,Xc,Processing line 26000000(20.91%)
# Xp,Xp,Xp,Xc,Xp,Xc,Xc,Xc,Xc,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xc,Xc,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Processing line 27000000(21.71%)
# Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Processing line 28000000(22.52%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 29000000(23.32%)
# Processing line 30000000(24.13%)
# Processing line 31000000(24.93%)
# Processing line 32000000(25.74%)
# Processing line 33000000(26.54%)
# Processing line 34000000(27.34%)
# Xp,Processing line 35000000(28.15%)
# Processing line 36000000(28.95%)
# Processing line 37000000(29.76%)
# Processing line 38000000(30.56%)
# Processing line 39000000(31.36%)
# Processing line 40000000(32.17%)
# Processing line 41000000(32.97%)
# Processing line 42000000(33.78%)
# Xp,Processing line 43000000(34.58%)
# Processing line 44000000(35.39%)
# Xc,Xp,Processing line 45000000(36.19%)
# Xc,Xp,Processing line 46000000(36.99%)
# Xp,Xp,Processing line 47000000(37.8%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 48000000(38.6%)
# Xc,Xc,Processing line 49000000(39.41%)
# Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xc,Processing line 50000000(40.21%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 51000000(41.02%)
# Xp,Xp,Xp,Xp,Xp,Xp,Processing line 52000000(41.82%)
# Xp,Xp,Processing line 53000000(42.62%)
# Xp,Xp,Xp,Processing line 54000000(43.43%)
# Processing line 55000000(44.23%)
# Processing line 56000000(45.04%)
# Processing line 57000000(45.84%)
# Processing line 58000000(46.65%)
# Xp,Processing line 59000000(47.45%)
# Processing line 60000000(48.25%)
# Xp,Processing line 61000000(49.06%)
# Xp,Processing line 62000000(49.86%)
# Processing line 63000000(50.67%)
# Processing line 64000000(51.47%)
# Processing line 65000000(52.27%)
# Processing line 66000000(53.08%)
# Xp,Xp,Xp,Processing line 67000000(53.88%)
# Xp,Xp,Xp,Processing line 68000000(54.69%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xc,Xc,Xp,Xc,Xp,Xp,Processing line 69000000(55.49%)
# Xc,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 70000000(56.3%)
# Xp,Xp,Xc,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 71000000(57.1%)
# Processing line 72000000(57.9%)
# Processing line 73000000(58.71%)
# Processing line 74000000(59.51%)
# Processing line 75000000(60.32%)
# Xp,Processing line 76000000(61.12%)
# Xp,Processing line 77000000(61.93%)
# Xp,Xp,Xp,Xp,Xp,Processing line 78000000(62.73%)
# Xc,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Processing line 79000000(63.53%)
# Xp,Xc,Xc,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Processing line 80000000(64.34%)
# Xc,Xp,Xp,Xp,Xp,Xp,Xc,Xp,Xp,Xp,Processing line 81000000(65.14%)
# Xp,Xp,Xp,Xp,Xp,Processing line 82000000(65.95%)
# Xp,Xp,Xp,Processing line 83000000(66.75%)
# Xp,Processing line 84000000(67.56%)
# Xp,Xp,Xp,Processing line 85000000(68.36%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 86000000(69.16%)
# Processing line 87000000(69.97%)
# Processing line 88000000(70.77%)
# Processing line 89000000(71.58%)
# Processing line 90000000(72.38%)
# Processing line 91000000(73.18%)
# Processing line 92000000(73.99%)
# Processing line 93000000(74.79%)
# Processing line 94000000(75.6%)
# Xp,Processing line 95000000(76.4%)
# Xp,Xp,Processing line 96000000(77.21%)
# Xp,Processing line 97000000(78.01%)
# Processing line 98000000(78.81%)
# Xp,Xp,Processing line 99000000(79.62%)
# Xc,Xp,Xp,Xp,Processing line 100000000(80.42%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 101000000(81.23%)
# Xc,Xp,Xc,Processing line 102000000(82.03%)
# Xp,Processing line 103000000(82.84%)
# Xp,Processing line 104000000(83.64%)
# Processing line 105000000(84.44%)
# Processing line 106000000(85.25%)
# Xc,Xc,Xp,Xp,Xp,Xp,Processing line 107000000(86.05%)
# Processing line 108000000(86.86%)
# Processing line 109000000(87.66%)
# Xc,Processing line 110000000(88.46%)
# Processing line 111000000(89.27%)
# Processing line 112000000(90.07%)
# Xp,Processing line 113000000(90.88%)
# Processing line 114000000(91.68%)
# Processing line 115000000(92.49%)
# Xp,Processing line 116000000(93.29%)
# Xp,Xp,Processing line 117000000(94.09%)
# Xp,Processing line 118000000(94.9%)
# Xp,Xp,Xp,Xc,Xp,Processing line 119000000(95.7%)
# Xc,Xp,Processing line 120000000(96.51%)
# Xp,Xp,Xp,Processing line 121000000(97.31%)
# Xp,Xp,Xp,Processing line 122000000(98.12%)
# Xp,Xp,Xp,Xp,Xp,Processing line 123000000(98.92%)
# Xp,Xp,Xp,Xp,Xp,Xp,Xp,Xp,Processing line 124000000(99.72%)
# Xc,Xc,Xp,Aggregated the reviews of 14785289 customers
# 0.67GB

# %% [markdown]
# ## Part 3 - Handle complex cases, where customer ids appear multiple times

# %%
# append to output file
f = open("/media/paul/Data/datasets/DSPC_reviews_association_mining/transactions_vertical.csv", "a")

dict_size = len(cust_id_to_prods)

id_no = 0
for cust_id in cust_id_to_prods:
    id_no = id_no + 1
    
    # print progress every 100,000 ids
    if ((id_no%100000) == 0):
        print('(' + str(round((id_no/dict_size)*100,2)) + '%)')
    
    # write y for the product they bought and ? otherwise
    output_line = ''
    for prod_cat in prod_cats:        
        if prod_cat in cust_id_to_prods[cust_id]:
            output_line = output_line + 'y,'
        else:
            output_line = output_line + '?,'
    output_line = output_line.strip(',') # remove unnecessary comma
    f.write(output_line + '\n')

f.close()
del cust_id_to_prods

print("Complete!")
# Out:
# Complete!
