# %% [markdown]
# Importing libraries

# %%
#!pip install mlxtend

# %%
import pandas as pd

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules
#pd.set_option('display.max_rows', 500)

# %% [markdown]
# Reading CSV file

# %%
data = pd.read_csv("transactions_vertical.csv")

# %%
data = data.replace({ '?':0 , 'y': 1})

# %% [markdown]
# Running fp growth

# %%
fp = fpgrowth(random_sample, min_support= 0.05, use_colnames= True)
fp.sort_values(by="support", ascending = False)
# Out:
#       support                                          itemsets
# 9    0.130947                                           (Books)
# 2    0.116963                          (Digital_Ebook_Purchase)
# 7    0.066548                                        (Wireless)
# 10   0.050259                                              (PC)
# 23   0.044841                                            (Home)
# 20   0.042790                                         (Apparel)
# 11   0.038819                          (Health & Personal Care)
# 21   0.036885                                          (Beauty)
# 12   0.035825                                     (Mobile_Apps)
# 4    0.035533                                         (Kitchen)
# 13   0.035335                                          (Sports)
# 1    0.034715                                            (Toys)
# 19   0.034345                                       (Video DVD)
# 5    0.031961                                           (Shoes)
# ...

# %% [markdown]
# Association Rules

# %%
fp_ar = association_rules(fp, metric='confidence', min_threshold= 0.7)
fp_ar.sort_values(by="confidence", ascending=False)
# Out:
#                   antecedents               consequents  antecedent support  \
# 37         (Video DVD, Music)                   (Books)            0.000914
# 38             (Music, Books)               (Video DVD)            0.001189
# 36         (Video DVD, Books)                   (Music)            0.001761
# 264                   (Video)                   (Books)            0.002626
# 152               (Video DVD)                   (Books)            0.034345
# 33                    (Music)                   (Books)            0.031563
# 35                    (Music)               (Video DVD)            0.031563
# 248                 (Grocery)                   (Books)            0.017440
# 34                (Video DVD)                   (Music)            0.034345
# 132         (Office Products)                   (Books)            0.019352
# 30   (Digital_Ebook_Purchase)                   (Books)            0.116963
# ...

# %%
fp_ar.shape #no of rules
# Out:
# (266, 10)
